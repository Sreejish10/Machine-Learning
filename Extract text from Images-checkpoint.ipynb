# %%
#extract DL number from DL image
#install pytesseract using pip install pytesseract
import pytesseract
# from pytho imaging library import Image module
from PIL import Image
#set the tesseract path in the script before calling image_to_string
#install tesseract from https://tesseract-ocr.github.io/tessdoc/Home.html
pytesseract.pytesseract.tesseract_cmd = r'C:\Users\sreejish\AppData\Local\Tesseract-OCR\tesseract.exe'
#place the DL image in same folder as code
img = Image.open('DL2.jpg')
pytesseract.get_tesseract_version()
#extract text from Image
text = pytesseract.image_to_string(img)
im1=img.resize((300,300))
im1
# Out:
# <PIL.Image.Image image mode=RGB size=300x300 at 0x2BCAF0C1E80>

# %%
text
# Out:
# "California’: DRIVER LICENSE SE,\n\nDL 11234568 _ se, CLASS C a\nexp 08/31/2014. END NONE\n\n» LNCARDHOLDER\nE FNIMA 7\n\nFy 2570 24TH\\STREET\nANYTOWN, CA 95818\n\n   \n\n08311977\n\n \n\nh\n\\ VETERAN\n)YSEX F EYES BRN\n\nrR BER\nHAGT-S'-05” WGT 125 Ib\nDD 00/00/0000NNNAN/ANFDIYY 08/31/2009"

# %%
#use regular expression to extract license number from DL
import re
regexobject = re.compile(r'DL (.\w+)')
Dlnumber=regexobject.findall(text)

# %%
Dlnumber
# Out:
# ['11234568']
